# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd

# %%
df1 = pd.read_csv('IMDB_Movie.csv')

# %%
df1.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df1.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df1.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
df1.sample(5)
# Out:
#      Rank          Title                       Genre  \
# 13     14          Moana  Animation,Adventure,Comedy
# 780   781        Unknown     Action,Mystery,Thriller
# 145   146      Ah-ga-ssi       Drama,Mystery,Romance
# 520   521     Anthropoid  Biography,History,Thriller
# 291   292  Pitch Perfect        Comedy,Music,Romance
#
#                                            Description            Director  \
# 13   In Ancient Polynesia, when a terrible curse in...        Ron Clements
# 780  A man awakens from a coma, only to discover th...  Jaume Collet-Serra
# 145  A woman is hired as a handmaiden to a Japanese...      Chan-wook Park
# 520  Based on the extraordinary true story of Opera...          Sean Ellis
# 291  Beca, a freshman at Barden University, is cajo...         Jason Moore
#
#                                                 Actors  Year  \
# 13   Auli'i Cravalho, Dwayne Johnson, Rachel House,...  2016
# 780  Liam Neeson, Diane Kruger, January Jones,Aidan...  2011
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df1.shape
# Out:
# (1000, 12)

# %%
# Duplicate Row

# %%
temp_df = df1.append(df1)

# %%
temp_df.shape
# Out:
# (2000, 12)

# %%
temp_df = temp_df.drop_duplicates()

# %%
temp_df.shape
# Out:
# (1000, 12)

# %%
temp_df = df1.append(df1)

# %%
temp_df.shape
# Out:
# (2000, 12)

# %%
temp_df.drop_duplicates(inplace=True)

# %%
temp_df.shape
# Out:
# (1000, 12)

# %%
temp_df = df1.append(df1)

# %%
temp_df.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
temp_df.shape
# Out:
# (2000, 12)

# %%
temp_df.drop_duplicates(inplace=True,keep=False)
temp_df.shape
# Out:
# (0, 12)

# %%
df1.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df1['Runtime (Minutes)']
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 995    111
# 996     94
# 997     98
# 998     93
# 999     87
# Name: Runtime (Minutes), Length: 1000, dtype: int64

# %%
df1.rename(columns={
    'Runtime (Minutes)':'Runtime',
    'Revenue (Millions)':'Revenue_Millions'
}, inplace=True)

# %%
df1.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue_Millions', 'Metascore'],
#       dtype='object')

# %%
df1.columns = ['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
       'runtime', 'rating', 'votes', 'revenue_millions', 'metascore']

# %%
df1.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
df1.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime  rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
df1.isnull()
# Out:
#       rank  title  genre  description  director  actors   year  runtime  \
# 0    False  False  False        False     False   False  False    False
# 1    False  False  False        False     False   False  False    False
# 2    False  False  False        False     False   False  False    False
# 3    False  False  False        False     False   False  False    False
# 4    False  False  False        False     False   False  False    False
# ..     ...    ...    ...          ...       ...     ...    ...      ...
# 995  False  False  False        False     False   False  False    False
# 996  False  False  False        False     False   False  False    False
# 997  False  False  False        False     False   False  False    False
# 998  False  False  False        False     False   False  False    False
# 999  False  False  False        False     False   False  False    False
#
#      rating  votes  revenue_millions  metascore
# 0     False  False             False      False
# ...

# %%
df1.isnull().sum()
# Out:
# rank                  0
# title                 0
# genre                 0
# description           0
# director              0
# actors                0
# year                  0
# runtime               0
# rating                0
# votes                 0
# revenue_millions    128
# metascore            64
# dtype: int64

# %%
df1.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
df1['title']
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: title, Length: 1000, dtype: object

# %%
df1[['title']]
# Out:
#                        title
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
# [1000 rows x 1 columns]

# %%
# loc - uses name
# iloc - uses index

# %%
df1.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime  rating  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014      121     8.1
# ...

# %%
out1 = df1.loc[10]
out1
# Out:
# rank                                                               11
# title                         Fantastic Beasts and Where to Find Them
# genre                                        Adventure,Family,Fantasy
# description         The adventures of writer Newt Scamander in New...
# director                                                  David Yates
# actors              Eddie Redmayne, Katherine Waterston, Alison Su...
# year                                                             2016
# runtime                                                           133
# rating                                                            7.5
# votes                                                          232072
# revenue_millions                                               234.02
# metascore                                                          66
# Name: 10, dtype: object

# %%
df1.iloc[ 10, 4]
# Out:
# 'David Yates'

# %%
df1.iloc[123:129]
# Out:
#      rank                            title                    genre  \
# 123   124             Boyka: Undisputed IV                   Action
# 124   125            The Dark Knight Rises          Action,Thriller
# 125   126                  The Jungle Book   Adventure,Drama,Family
# 126   127  Transformers: Age of Extinction  Action,Adventure,Sci-Fi
# 127   128                            Nerve  Adventure,Crime,Mystery
# 128   129                       Mamma Mia!    Comedy,Family,Musical
#
#                                            description           director  \
# 123  In the fourth installment of the fighting fran...    Todor Chapkanov
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# 125  After a threat from the tiger Shere Khan force...        Jon Favreau
# 126  Autobots must escape sight from a bounty hunte...        Michael Bay
# 127  A high school senior finds herself immersed in...        Henry Joost
# ...

# %%
df1['director'] == 'Jon Favreau'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: director, Length: 1000, dtype: bool

# %%
df1[df1['director'] == 'Jon Favreau']
# Out:
#      rank            title                    genre  \
# 125   126  The Jungle Book   Adventure,Drama,Family
# 203   204         Iron Man  Action,Adventure,Sci-Fi
# 450   451       Iron Man 2  Action,Adventure,Sci-Fi
# 761   762             Chef             Comedy,Drama
#
#                                            description     director  \
# 125  After a threat from the tiger Shere Khan force...  Jon Favreau
# 203  After being held captive in an Afghan cave, bi...  Jon Favreau
# 450  With the world now aware of his identity as Ir...  Jon Favreau
# 761  A head chef quits his restaurant job and buys ...  Jon Favreau
#
#                                                 actors  year  runtime  rating  \
# 125  Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba  2016      106     7.5
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence H...  2008      126     7.9
# 450  Robert Downey Jr., Mickey Rourke, Gwyneth Palt...  2010      124     7.0
# ...

# %%
df1['rating'] > 8.6
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: rating, Length: 1000, dtype: bool

# %%
rating_great_8point6 = df1[df1['rating'] > 8.6]

# %%
rating_great_8point6
# Out:
#      rank            title                    genre  \
# 54     55  The Dark Knight       Action,Crime,Drama
# 80     81        Inception  Action,Adventure,Sci-Fi
# 117   118           Dangal   Action,Biography,Drama
#
#                                            description           director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
#
#                                                 actors  year  runtime  rating  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008      152     9.0
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010      148     8.8
# 117  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016      161     8.8
#
#        votes  revenue_millions  metascore
# 54   1791916            533.32       82.0
# 80   1583625            292.57       74.0
# ...

# %%
df1[(df1['director'] == 'Jon Favreau') & (df1['rating'] > 7.3)]
# Out:
#      rank            title                    genre  \
# 125   126  The Jungle Book   Adventure,Drama,Family
# 203   204         Iron Man  Action,Adventure,Sci-Fi
#
#                                            description     director  \
# 125  After a threat from the tiger Shere Khan force...  Jon Favreau
# 203  After being held captive in an Afghan cave, bi...  Jon Favreau
#
#                                                 actors  year  runtime  rating  \
# 125  Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba  2016      106     7.5
# 203  Robert Downey Jr., Gwyneth Paltrow, Terrence H...  2008      126     7.9
#
#       votes  revenue_millions  metascore
# 125  198243             364.0       77.0
# 203  737719             318.3       79.0

# %%
df1['rating']
# Out:
# 0      8.1
# 1      7.0
# 2      7.3
# 3      7.2
# 4      6.2
#       ...
# 995    6.2
# 996    5.5
# 997    6.2
# 998    5.6
# 999    5.3
# Name: rating, Length: 1000, dtype: float64

# %%
def rate_rating(x):
    if x > 5.0:
        return 'Good'
    else:
        return 'Bad'

# %%
rate_rating(7.5)
# Out:
# 'Good'

# %%
rate_rating(2.0)
# Out:
# 'Bad'

# %%
df1.shape
# Out:
# (1000, 12)

# %%
df1.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
df1['rating_category'] = df1['rating'].apply(rate_rating)

# %%
df1.shape
# Out:
# (1000, 13)

# %%
df1.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore',
#        'rating_category'],
#       dtype='object')

# %%
df1.tail()
# Out:
#      rank                   title                  genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            description          director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 actors  year  runtime  rating  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015      111     6.2
# ...

# %%
df1.plot(x = 'rating', y = 'revenue_millions', kind = 'scatter')
